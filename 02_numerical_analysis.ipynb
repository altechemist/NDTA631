# %%
# NDTA631 - Data Analysis and Visualization
import numpy as np
import os

print('Starting NDTA631 Assignment Analysis...')
print('Loading datasets...')
# Out:
# Starting NDTA631 Assignment Analysis...
# Loading datasets...

# %%
# --- Load datasets with proper Windows paths ---
sent_df = pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\WB_FINDEX_FIN13BM.csv")

sent_df
# Out:
#          STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 1    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 2    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 3    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 4    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# ..             ...                         ...    ...  ...        ...
# 510  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 511  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 512  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 513  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 514  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
#
#     REF_AREA                              REF_AREA_LABEL          INDICATOR  \
# 0        BGD                                  Bangladesh  WB_FINDEX_FIN13BM
# 1        BEN                                       Benin  WB_FINDEX_FIN13BM
# 2        BWA                                    Botswana  WB_FINDEX_FIN13BM
# 3        BFA                                Burkina Faso  WB_FINDEX_FIN13BM
# 4        KHM                                    Cambodia  WB_FINDEX_FIN13BM
# ..       ...                                         ...                ...
# 510      TGO                                        Togo  WB_FINDEX_FIN13BM
# 511      UGA                                      Uganda  WB_FINDEX_FIN13BM
# 512      ZMB                                      Zambia  WB_FINDEX_FIN13BM
# 513      ZWE                                    Zimbabwe  WB_FINDEX_FIN13BM
# 514      SSA  Sub-Saharan Africa (excluding high income)  WB_FINDEX_FIN13BM
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT  \
# 0    Sent money from a mobile money account, monthly  _T  ...         0
# 1    Sent money from a mobile money account, monthly  _T  ...         0
# 2    Sent money from a mobile money account, monthly  _T  ...         0
# 3    Sent money from a mobile money account, monthly  _T  ...         0
# 4    Sent money from a mobile money account, monthly  _T  ...         0
# ..                                               ...  ..  ...       ...
# 510  Sent money from a mobile money account, monthly  _T  ...         0
# 511  Sent money from a mobile money account, monthly  _T  ...         0
# 512  Sent money from a mobile money account, monthly  _T  ...         0
# 513  Sent money from a mobile money account, monthly  _T  ...         0
# 514  Sent money from a mobile money account, monthly  _T  ...         0
#
#     UNIT_MULT_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0             Units     RATIO           Ratio         602              CCYY
# 1             Units     RATIO           Ratio         602              CCYY
# 2             Units     RATIO           Ratio         602              CCYY
# 3             Units     RATIO           Ratio         602              CCYY
# 4             Units     RATIO           Ratio         602              CCYY
# ..              ...       ...             ...         ...               ...
# 510           Units     RATIO           Ratio         602              CCYY
# 511           Units     RATIO           Ratio         602              CCYY
# 512           Units     RATIO           Ratio         602              CCYY
# 513           Units     RATIO           Ratio         602              CCYY
# 514           Units     RATIO           Ratio         602              CCYY
#
#     OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0            A     Normal value       PU         Public
# 1            A     Normal value       PU         Public
# 2            A     Normal value       PU         Public
# 3            A     Normal value       PU         Public
# 4            A     Normal value       PU         Public
# ..         ...              ...      ...            ...
# 510          A     Normal value       PU         Public
# 511          A     Normal value       PU         Public
# 512          A     Normal value       PU         Public
# 513          A     Normal value       PU         Public
# 514          A     Normal value       PU         Public
#
# [515 rows x 37 columns]

# %%
withdrew_df = pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\WB_FINDEX_FIN13CM.csv")

withdrew_df
# Out:
#          STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 1    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 2    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 3    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 4    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# ..             ...                         ...    ...  ...        ...
# 510  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 511  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 512  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 513  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 514  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
#
#     REF_AREA                              REF_AREA_LABEL          INDICATOR  \
# 0        BGD                                  Bangladesh  WB_FINDEX_FIN13CM
# 1        BEN                                       Benin  WB_FINDEX_FIN13CM
# 2        BWA                                    Botswana  WB_FINDEX_FIN13CM
# 3        BFA                                Burkina Faso  WB_FINDEX_FIN13CM
# 4        KHM                                    Cambodia  WB_FINDEX_FIN13CM
# ..       ...                                         ...                ...
# 510      TGO                                        Togo  WB_FINDEX_FIN13CM
# 511      UGA                                      Uganda  WB_FINDEX_FIN13CM
# 512      ZMB                                      Zambia  WB_FINDEX_FIN13CM
# 513      ZWE                                    Zimbabwe  WB_FINDEX_FIN13CM
# 514      SSA  Sub-Saharan Africa (excluding high income)  WB_FINDEX_FIN13CM
#
#                                        INDICATOR_LABEL SEX  ... UNIT_MULT  \
# 0    Took out money from a mobile money account, mo...  _T  ...         0
# 1    Took out money from a mobile money account, mo...  _T  ...         0
# 2    Took out money from a mobile money account, mo...  _T  ...         0
# 3    Took out money from a mobile money account, mo...  _T  ...         0
# 4    Took out money from a mobile money account, mo...  _T  ...         0
# ..                                                 ...  ..  ...       ...
# 510  Took out money from a mobile money account, mo...  _T  ...         0
# 511  Took out money from a mobile money account, mo...  _T  ...         0
# 512  Took out money from a mobile money account, mo...  _T  ...         0
# 513  Took out money from a mobile money account, mo...  _T  ...         0
# 514  Took out money from a mobile money account, mo...  _T  ...         0
#
#     UNIT_MULT_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0             Units     RATIO           Ratio         602              CCYY
# 1             Units     RATIO           Ratio         602              CCYY
# 2             Units     RATIO           Ratio         602              CCYY
# 3             Units     RATIO           Ratio         602              CCYY
# 4             Units     RATIO           Ratio         602              CCYY
# ..              ...       ...             ...         ...               ...
# 510           Units     RATIO           Ratio         602              CCYY
# 511           Units     RATIO           Ratio         602              CCYY
# 512           Units     RATIO           Ratio         602              CCYY
# 513           Units     RATIO           Ratio         602              CCYY
# 514           Units     RATIO           Ratio         602              CCYY
#
#     OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0            A     Normal value       PU         Public
# 1            A     Normal value       PU         Public
# 2            A     Normal value       PU         Public
# 3            A     Normal value       PU         Public
# 4            A     Normal value       PU         Public
# ..         ...              ...      ...            ...
# 510          A     Normal value       PU         Public
# 511          A     Normal value       PU         Public
# 512          A     Normal value       PU         Public
# 513          A     Normal value       PU         Public
# 514          O    Missing value       PU         Public
#
# [515 rows x 37 columns]

# %%
# Clean data by removing NaN values
sent_df_clean = sent_df.dropna(subset=['OBS_VALUE'])
withdrew_df_clean = withdrew_df.dropna(subset=['OBS_VALUE'])

# %%
sent_df_clean
# Out:
#          STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 1    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 2    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 3    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 4    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# ..             ...                         ...    ...  ...        ...
# 510  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 511  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 512  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 513  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 514  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
#
#     REF_AREA                              REF_AREA_LABEL          INDICATOR  \
# 0        BGD                                  Bangladesh  WB_FINDEX_FIN13BM
# 1        BEN                                       Benin  WB_FINDEX_FIN13BM
# 2        BWA                                    Botswana  WB_FINDEX_FIN13BM
# 3        BFA                                Burkina Faso  WB_FINDEX_FIN13BM
# 4        KHM                                    Cambodia  WB_FINDEX_FIN13BM
# ..       ...                                         ...                ...
# 510      TGO                                        Togo  WB_FINDEX_FIN13BM
# 511      UGA                                      Uganda  WB_FINDEX_FIN13BM
# 512      ZMB                                      Zambia  WB_FINDEX_FIN13BM
# 513      ZWE                                    Zimbabwe  WB_FINDEX_FIN13BM
# 514      SSA  Sub-Saharan Africa (excluding high income)  WB_FINDEX_FIN13BM
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT  \
# 0    Sent money from a mobile money account, monthly  _T  ...         0
# 1    Sent money from a mobile money account, monthly  _T  ...         0
# 2    Sent money from a mobile money account, monthly  _T  ...         0
# 3    Sent money from a mobile money account, monthly  _T  ...         0
# 4    Sent money from a mobile money account, monthly  _T  ...         0
# ..                                               ...  ..  ...       ...
# 510  Sent money from a mobile money account, monthly  _T  ...         0
# 511  Sent money from a mobile money account, monthly  _T  ...         0
# 512  Sent money from a mobile money account, monthly  _T  ...         0
# 513  Sent money from a mobile money account, monthly  _T  ...         0
# 514  Sent money from a mobile money account, monthly  _T  ...         0
#
#     UNIT_MULT_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0             Units     RATIO           Ratio         602              CCYY
# 1             Units     RATIO           Ratio         602              CCYY
# 2             Units     RATIO           Ratio         602              CCYY
# 3             Units     RATIO           Ratio         602              CCYY
# 4             Units     RATIO           Ratio         602              CCYY
# ..              ...       ...             ...         ...               ...
# 510           Units     RATIO           Ratio         602              CCYY
# 511           Units     RATIO           Ratio         602              CCYY
# 512           Units     RATIO           Ratio         602              CCYY
# 513           Units     RATIO           Ratio         602              CCYY
# 514           Units     RATIO           Ratio         602              CCYY
#
#     OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0            A     Normal value       PU         Public
# 1            A     Normal value       PU         Public
# 2            A     Normal value       PU         Public
# 3            A     Normal value       PU         Public
# 4            A     Normal value       PU         Public
# ..         ...              ...      ...            ...
# 510          A     Normal value       PU         Public
# 511          A     Normal value       PU         Public
# 512          A     Normal value       PU         Public
# 513          A     Normal value       PU         Public
# 514          A     Normal value       PU         Public
#
# [333 rows x 37 columns]

# %%
withdrew_df_clean
# Out:
#          STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 1    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 2    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 3    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 4    datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# ..             ...                         ...    ...  ...        ...
# 509  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 510  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 511  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 512  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
# 513  datastructure  WB.DATA360:DS_DATA360(1.2)      I   A3  Triennial
#
#     REF_AREA REF_AREA_LABEL          INDICATOR  \
# 0        BGD     Bangladesh  WB_FINDEX_FIN13CM
# 1        BEN          Benin  WB_FINDEX_FIN13CM
# 2        BWA       Botswana  WB_FINDEX_FIN13CM
# 3        BFA   Burkina Faso  WB_FINDEX_FIN13CM
# 4        KHM       Cambodia  WB_FINDEX_FIN13CM
# ..       ...            ...                ...
# 509      TZA       Tanzania  WB_FINDEX_FIN13CM
# 510      TGO           Togo  WB_FINDEX_FIN13CM
# 511      UGA         Uganda  WB_FINDEX_FIN13CM
# 512      ZMB         Zambia  WB_FINDEX_FIN13CM
# 513      ZWE       Zimbabwe  WB_FINDEX_FIN13CM
#
#                                        INDICATOR_LABEL SEX  ... UNIT_MULT  \
# 0    Took out money from a mobile money account, mo...  _T  ...         0
# 1    Took out money from a mobile money account, mo...  _T  ...         0
# 2    Took out money from a mobile money account, mo...  _T  ...         0
# 3    Took out money from a mobile money account, mo...  _T  ...         0
# 4    Took out money from a mobile money account, mo...  _T  ...         0
# ..                                                 ...  ..  ...       ...
# 509  Took out money from a mobile money account, mo...  _T  ...         0
# 510  Took out money from a mobile money account, mo...  _T  ...         0
# 511  Took out money from a mobile money account, mo...  _T  ...         0
# 512  Took out money from a mobile money account, mo...  _T  ...         0
# 513  Took out money from a mobile money account, mo...  _T  ...         0
#
#     UNIT_MULT_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0             Units     RATIO           Ratio         602              CCYY
# 1             Units     RATIO           Ratio         602              CCYY
# 2             Units     RATIO           Ratio         602              CCYY
# 3             Units     RATIO           Ratio         602              CCYY
# 4             Units     RATIO           Ratio         602              CCYY
# ..              ...       ...             ...         ...               ...
# 509           Units     RATIO           Ratio         602              CCYY
# 510           Units     RATIO           Ratio         602              CCYY
# 511           Units     RATIO           Ratio         602              CCYY
# 512           Units     RATIO           Ratio         602              CCYY
# 513           Units     RATIO           Ratio         602              CCYY
#
#     OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0            A     Normal value       PU         Public
# 1            A     Normal value       PU         Public
# 2            A     Normal value       PU         Public
# 3            A     Normal value       PU         Public
# 4            A     Normal value       PU         Public
# ..         ...              ...      ...            ...
# 509          A     Normal value       PU         Public
# 510          A     Normal value       PU         Public
# 511          A     Normal value       PU         Public
# 512          A     Normal value       PU         Public
# 513          A     Normal value       PU         Public
#
# [320 rows x 37 columns]

# %%
# Convert to NumPy arrays
sent_values = sent_df_clean['OBS_VALUE'].to_numpy(dtype=float)
withdrew_values = withdrew_df_clean['OBS_VALUE'].to_numpy(dtype=float)
if len(sent_values) > 1 and len(withdrew_values) > 1:

       # --- NumPy Calculations ---
    sent_mean, sent_median, sent_std = np.mean(sent_values), np.median(sent_values), np.std(sent_values)
   
    
    withdrew_mean, withdrew_median, withdrew_std = np.mean(withdrew_values), np.median(withdrew_values), np.std(withdrew_values)

# %%
    print(f"Sent Money   Mean: {sent_mean:.2f}, Median: {sent_median:.2f}, Std: {sent_std:.2f}")
# Out:
# Sent Money   Mean: 16.12, Median: 15.20, Std: 7.25

# %%
    print(f"Withdrew Money Mean: {withdrew_mean:.2f}, Median: {withdrew_median:.2f}, Std: {withdrew_std:.2f}")
# Out:
# Withdrew Money Mean: 16.13, Median: 15.50, Std: 6.60

# %%
# --- Reshape Arrays (2 columns) ---
if len(sent_values) % 2 != 0:
        sent_values = sent_values[:-1]  # drop last if odd
if len(withdrew_values) % 2 != 0:
        withdrew_values = withdrew_values[:-1]

sent_reshaped = sent_values.reshape(-1, 2)
withdrew_reshaped = withdrew_values.reshape(-1, 2)

# %%
sent_reshaped[:5]
# Out:
# array([[ 3.4114798 , 11.2210111 ],
#        [19.78814569, 10.73053513],
#        [ 3.48643169, 12.88795819],
#        [ 2.39687495,  3.08939273],
#        [ 8.52783193,  9.64203606]])

# %%
withdrew_reshaped[:5]
# Out:
# array([[ 5.07788953, 15.19596138],
#        [17.45249856, 10.21599398],
#        [ 2.9252437 , 12.07635567],
#        [ 1.59066285,  2.96812008],
#        [ 8.23140896, 10.80244449]])

# %%
# --- Element-wise Operations ---
min_len = min(len(sent_values), len(withdrew_values))
ratio = withdrew_values[:min_len] / (sent_values[:min_len] + 1e-6)

print("\nElement-wise Ratio (Withdrew / Sent) - first 10 values:")
ratio[:10]
# Out:
# Element-wise Ratio (Withdrew / Sent) - first 10 values:
# array([1.48847079, 1.3542416 , 0.88196731, 0.95204879, 0.83903633,
#        0.93702622, 0.66364004, 0.96074516, 0.96524041, 1.12034878])

# %%
    # --- Correlation ---
    if np.std(sent_values[:min_len]) > 0 and np.std(withdrew_values[:min_len]) > 0:
        correlation = np.corrcoef(sent_values[:min_len], withdrew_values[:min_len])[0, 1]
        print(f"\nCorrelation between Sent and Withdrew: {correlation:.2f}")
    else:
        print("\nCorrelation cannot be computed (no variation in data).")
# Out:
# Correlation between Sent and Withdrew: 0.55

# %%
sent_df_clean.to_csv(r"C:\Users\Admin\OneDrive\Documents\sent_df_clean.csv")
withdrew_df_clean.to_csv(r"C:\Users\Admin\OneDrive\Documents\withdrews_df_clean.csv")

# %%
# Initialize git (only the first time)
# !git init
# !git branch -M main
# !git remote add origin notebooks/02_numerical_analysis.ipynb
# Out:
# Reinitialized existing Git repository in C:/Users/Admin/.git/

# %%
# !git add .
# Out:
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/compilePluginWithoutConfiguration/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/enforcerplugin/some-thing/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/expandProperties/some-thing/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/flatmultimodule/some-thing/webinar-api/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/flatmultimodule/some-thing/webinar-impl/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/flatmultimodule/some-thing/webinar-parent/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/flatmultimodule/some-thing/webinar-war/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/insecureProtocolAllow/some-thing/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/insecureProtocolDefaultHandling/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/insecureProtocolFail/some-thing/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/insecureProtocolUpgrade/some-thing/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/insecureProtocolWarn/some-thing/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/javadocJar/some-thing/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/javadocJar/some-thing/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/mavenExtensions/some-thing/test-core/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/multiModule/some-thing/webinar-api/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/multiModule/some-thing/webinar-impl/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/multiModule/some-thing/webinar-war/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/multiModuleNoBackReferences/some-thing/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/multiModuleWithNestedParent/some-thing/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/multiModuleWithRemoteParent/some-thing/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/remoteparent/some-thing/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/sharedResources/maven_home/m2_home/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/sharedResources/maven_repo/util/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/singleModule/some-thing/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/singleModule/some-thing/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/sourcesJar/some-thing/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/sourcesJar/some-thing/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/testsJar/some-thing/src/main/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/build-init/src/integTest/resources/org/gradle/buildinit/plugins/MavenConversionIntegrationTest/testsJar/some-thing/src/test/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/dependency-management/src/integTest/resources/org/gradle/integtests/resolve/ArtifactDependenciesIntegrationTest/canHaveConfigurationHierarchy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/dependency-management/src/integTest/resources/org/gradle/integtests/resolve/ArtifactDependenciesIntegrationTest/canHaveCycleInDependencyGraph/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/dependency-management/src/integTest/resources/org/gradle/integtests/resolve/ArtifactDependenciesIntegrationTest/canUseDynamicVersions/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/dependency-management/src/integTest/resources/org/gradle/integtests/resolve/ArtifactDependenciesIntegrationTest/dependencyReportWithConflicts/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/dependency-management/src/integTest/resources/org/gradle/integtests/resolve/verification/DependencyVerificationSignatureWriteIntegTest/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/dependency-management/src/test/resources/org/gradle/api/internal/artifacts/ivyservice/modulecache/ModuleMetadataSerializerTest/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/diagnostics/src/integTest/resources/org/gradle/api/tasks/diagnostics/HelpTaskIntegrationTest/listsCommonDynamicAvailableValues/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/diagnostics/src/integTest/resources/org/gradle/api/tasks/diagnostics/HelpTaskIntegrationTest/listsEnumAndBooleanCmdOptionValues/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/build-organization/composite-builds/declared-substitution/groovy/anonymous-library/src/main/java/org/sample/numberutils/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/build-organization/composite-builds/declared-substitution/kotlin/anonymous-library/src/main/java/org/sample/numberutils/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/build-organization/composite-builds/hierarchical-multirepo/groovy/modules/number-utils/src/main/java/org/sample/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/build-organization/composite-builds/hierarchical-multirepo/groovy/modules/string-utils/src/main/java/org/sample/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/build-organization/composite-builds/hierarchical-multirepo/kotlin/modules/number-utils/src/main/java/org/sample/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/build-organization/composite-builds/hierarchical-multirepo/kotlin/modules/string-utils/src/main/java/org/sample/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/incubating/build-organization/publishing-convention-plugins/groovy/convention-plugins/src/test/groovy/com/myorg/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/incubating/build-organization/publishing-convention-plugins/kotlin/convention-plugins/src/test/kotlin/com/myorg/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/templates/build-src-plugin-java-module-transform/buildSrc/src/main/java/org/gradle/sample/transform/javamodules/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/templates/java-junit5-integration-test-for-application/src/integrationTest/java/org/gradle/sample/integtest/app/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/templates/java-junit5-integration-test-for-utilities-library/src/integrationTest/java/org/gradle/sample/integtest/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/templates/structuring-software-projects/admin-feature/config/src/main/kotlin/com/example/myproduct/admin/config/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/templates/structuring-software-projects/admin-feature/config/src/test/kotlin/com/example/myproduct/admin/config/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/templates/structuring-software-projects/state/application-state/src/main/kotlin/com/example/myproduct/admin/state/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/samples/writing-tasks/tasks-with-dependency-resolution-result-inputs/common/dependency-reports/src/main/java/com/example/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/customizingResolution-conditionalSubstitutionRule/groovy/repo/org.example/project1/1.0/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/customizingResolution-conditionalSubstitutionRule/groovy/repo/org.example/project2/1.0/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/customizingResolution-conditionalSubstitutionRule/groovy/repo/org.example/project3/1.0/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/customizingResolution-conditionalSubstitutionRule/kotlin/repo/org.example/project1/1.0/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/customizingResolution-conditionalSubstitutionRule/kotlin/repo/org.example/project2/1.0/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/customizingResolution-conditionalSubstitutionRule/kotlin/repo/org.example/project3/1.0/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/managingTransitiveDependencies-dependencyAlignmentWithPlatform/groovy/buildSrc/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/managingTransitiveDependencies-dependencyAlignmentWithPlatform/kotlin/buildSrc/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/modelingFeatures-crossProjectPublications-advanced-published/groovy/buildSrc/src/main/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/docs/src/snippets/dependencyManagement/modelingFeatures-crossProjectPublications-advanced-published/kotlin/buildSrc/src/main/kotlin/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/api/src/integTest/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/api/src/main/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/api/src/main/resources/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/api/src/main/testbutnottest/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/api/src/test/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/api/src/test/resources/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/api/src/test/t_e_s_t/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/common/src/main/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/common/src/main/resources/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/common/src/test/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/groovyproject/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/webAppJava6/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/webAppWithVars/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/eclipse/EclipseIntegrationTest/canCreateAndDeleteMetaData/webservice/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/idea/IdeaIntegrationTest/canCreateAndDeleteMetaData/api/src/main/java/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/idea/IdeaIntegrationTest/canCreateAndDeleteMetaData/api/src/test/java/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/idea/IdeaIntegrationTest/canCreateAndDeleteMetaData/expectedFiles/webservice/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/idea/IdeaIntegrationTest/canCreateAndDeleteMetaData/webservice/src/main/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/ide/src/integTest/resources/org/gradle/plugins/ide/idea/IdeaIntegrationTest/worksWithASubProjectThatDoesNotHaveTheIdeaPluginApplied/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/integ-test/src/integTest/resources/org/gradle/integtests/ProjectLayoutIntegrationTest/canUseANonStandardBuildDir/src/main/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/integ-test/src/integTest/resources/org/gradle/integtests/ProjectLayoutIntegrationTest/canUseANonStandardBuildDir/src/test/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/language-java/src/integTest/resources/org/gradle/api/tasks/javadoc/JavadocIntegrationTest/canCombineLocalOptionWithOtherOptions/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/language-java/src/integTest/resources/org/gradle/api/tasks/javadoc/JavadocIntegrationTest/handlesTagsAndTaglets/src/main/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/language-java/src/integTest/resources/org/gradle/api/tasks/javadoc/JavadocIntegrationTest/handlesTagsAndTaglets/src/taglet/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/ApiGroovyCompilerIntegrationSpec/canEnableAndDisableAllOptimizations/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/ApiGroovyCompilerIntegrationSpec/canEnableAndDisableIntegerOptimization/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/ApiGroovyCompilerIntegrationSpec/canUseCustomFileExtensions/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/canCompileAgainstGroovyClassThatDependsOnExternalClass/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/canListSourceFiles/src/main/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/compileBadJavaCode/src/main/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/compileJavaFx8Code/src/main/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/configurationScriptNotSupported/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/failsBecauseOfInvalidConfigFile/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/failsBecauseOfMissingConfigFile/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/groovyToolClassesAreNotVisible/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/BasicGroovyCompilerIntegrationSpec/useConfigurationScript/src/main/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canJointCompileWithJavaCompilerExecutable/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canUseAstTransformThatReferencesGroovyTestCase/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canUseAstTransformWithAsm/src/main/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canUseAstTransformWithAsm/src/test/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canUseAstTransformWrittenInGroovy/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canUseBuiltInAstTransform/src/test/groovy/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canUseThirdPartyAstTransform/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/canUseThirdPartyAstTransform/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/gradle3235/src/main/groovy/com/example/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/GroovyCompilerIntegrationSpec/gradle3235/src/main/resources/META-INF/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/IncrementalGroovyCompileIntegrationTest/failsCompilationWhenConfigScriptIsUpdated/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/IncrementalGroovyCompileIntegrationTest/recompilesDependentClasses/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/IncrementalGroovyCompileIntegrationTest/recompilesSourceWhenPropertiesChange/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/plugins/src/integTest/resources/org/gradle/groovy/compile/InvokeDynamicGroovyCompilerSpec/canEnableAndDisableInvokeDynamicOptimization/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/scala/src/integTest/resources/org/gradle/scala/compile/IncrementalScalaCompileIntegrationTest/recompilesDependentClasses/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/scala/src/integTest/resources/org/gradle/scala/compile/IncrementalScalaCompileIntegrationTest/recompilesSourceWhenPropertiesChange/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/scala/src/integTest/resources/org/gradle/scala/compile/IncrementalScalaCompileIntegrationTest/restoresClassesOnCompilationFailure/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/scala/src/integTest/resources/org/gradle/scala/compile/ScalaCompileWithJavaLibraryIntegrationTest/javaLibraryCanDependOnScalaLibraryProject/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/android-kotlin-example/app/src/main/kotlin/org/gradle/smoketest/kotlin/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/android-kotlin-example/app/src/test/kotlin/org/gradle/smoketest/kotlin/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/android-kotlin-example-kotlin-dsl/app/src/main/kotlin/org/gradle/smoketest/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/android-kotlin-example-kotlin-dsl/app/src/test/kotlin/org/gradle/smoketest/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/gmm-example/consumer/android-kotlin-app/src/main/java/org/gradle/example2/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/gmm-example/producer/android-kotlin-library/src/main/kotlin/example/androidkotlinlib/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/gmm-example/producer/android-library/src/main/java/example/androidlib/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/gmm-example/producer/android-library-single-variant/src/main/java/example/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/gmm-example/producer/kotlin-library/src/main/kotlin/example/kotlinlib/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/gmm-example/producer/kotlin-multiplatform-android-library/src/commonMain/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/smoke-test/src/smokeTest/resources/org/gradle/smoketests/gmm-example/producer/kotlin-multiplatform-library/src/commonMain/kotlin/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-base/src/integTest/resources/org/gradle/api/internal/tasks/testing/JULRedirectorIntegrationTest/loggingConfig/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-base/src/integTest/resources/org/gradle/api/internal/tasks/testing/JULRedirectorIntegrationTest/loggingConfig/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-base/src/integTest/resources/org/gradle/testing/RetainStacktraceForInheritedTestMethodsTest/retainsStackTraceForInheritedTestMethods/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-base/src/integTest/resources/org/gradle/testing/TestExecutionBuildOperationsIntegrationTest/emitsBuildOperationsForJUnitTests/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-base/src/integTest/resources/org/gradle/testing/TestExecutionBuildOperationsIntegrationTest/emitsBuildOperationsForTestNgTests/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/cucumberjvm/CucumberJVMReportIntegrationTest/testReportingSupportsCucumberStepsWithSlashes/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/IncrementalTestIntegrationTest/executesTestsWhenSourceChanges/src/main/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/IncrementalTestIntegrationTest/executesTestsWhenTestFrameworkChanges/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitAbortedTestClassIntegrationTest/supportsAssumptionsInRules/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitAssumptionsIntegrationTest/supportsAssumptions/src/test/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitCategoriesIntegrationSpec/reExecutesWhenPropertyIsChanged/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitCategoriesIntegrationSpec/reportsUnloadableCategories/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitCategoriesIntegrationSpec/supportsCategoriesAndNullTestClassDescription/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitCategoriesIntegrationSpec/testTaskFailsIfCategoriesNotSupported/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitConsoleLoggingIntegrationTest/shared/src/test/groovy/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitConsoleLoggingIntegrationTest/standardOutputLogging/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIgnoreClassMultiVersionIntegrationSpec/canHandleClassLevelIgnoredTests/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/canHaveMultipleTestTaskInstances/src/test/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/canHaveMultipleTestTaskInstances/src/test2/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/createsRunnerBeforeTests/src/test/java/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/detectsTestClasses/src/test/java/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/executesTestsInCorrectEnvironment/src/test/java/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/reportsAndBreaksBuildWhenTestFails/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/suitesOutputIsVisible/src/test/java/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/supportsJunit3Suites/src/test/java/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/supportsTestCategories/src/test/java/org/gradle/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitIntegrationTest/testClassesCanBeSharedByMultipleSuites/src/test/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/junit/JUnitJdkNavigationIntegrationTest/shouldNotNavigateToJdkClasses/src/': Filename too long
# warning: could not open directory '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/subprojects/testing-jvm/src/integTest/resources/org/gradle/testing/testng/TestNGFailurePolicyIntegrationTest/shared/src/test/java/org/gradle/': Filename too long
# ...
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic-commons/gradle-plugin/src/main/kotlin/gradlebuild/testcleanup/TestFilesCleanupService.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic-commons/gradle-plugin/src/main/kotlin/gradlebuild/testcleanup/extension/TestFileCleanUpExtension.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic-commons/gradle-plugin/src/main/kotlin/gradlebuild/testcleanup/extension/TestFilesCleanupBuildServiceRootExtension.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic-commons/gradle-plugin/src/main/kotlin/gradlebuild/testcleanup/extension/TestFilesCleanupProjectState.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic-commons/settings.gradle.kts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/build.gradle.kts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild.minify.gradle.kts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild.repositories.gradle.kts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild.reproducible-archives.gradle.kts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/BuildEnvironment.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/BuildParams.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/GradleModuleApiAttribute.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/PublicApi.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/PublicKotlinDslApi.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/accessors/accessors.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/classanalysis/AnalyzeAndShade.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/classanalysis/ClassAnalysisException.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/classanalysis/ClassGraph.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/kotlindsl/kotlin-dsl-upstream-candidates.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/repositories-extensions.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/tasks/ClasspathManifest.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/tasks/PackageListGenerator.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/testing/TestType.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/transforms/Minify.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/util/KotlinSourceParser.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/main/kotlin/gradlebuild/basics/util/ReproduciblePropertiesWriter.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/basics/src/test/kotlin/gradlebuild/basics/tasks/PackageListGeneratorIntegrationTest.kt', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/build.gradle.kts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild.binary-compatibility.gradle', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/EnrichedReportRenderer.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/AcceptedApiChange.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/AcceptedApiChanges.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/AcceptedApiChangesJsonFileManager.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/ApiChange.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/BinaryCompatibilityHelper.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/CleanAcceptedApiChanges.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/JapicmpTask.java', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/filters/AnonymousClassesFilter.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/filters/KotlinInternalFilter.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/AbstractGradleViolationRule.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/AbstractSuperClassChangesRule.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/AcceptedRegressionsRulePostProcess.java', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/AcceptedRegressionsRuleSetup.java', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/BinaryBreakingChangesRule.java', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/BinaryBreakingSuperclassChangeRule.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/IncubatingInternalInterfaceAddedRule.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/IncubatingMissingRule.java', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/KotlinModifiersBreakingChangeRule.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/MethodsRemovedInInternalSuperClassRule.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/NewIncubatingAPIRule.java', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/NullabilityBreakingChangesRule.groovy', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/SinceAnnotationMissingRule.java', LF will be replaced by CRLF the next time Git touches it
# error: open(".gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/SinceAnnotationMissingRuleCurrentGradleVersionSetup.java"): Filename too long
# error: unable to index file '.gradle/caches/transforms-3/c762f17d69b567ffc4fbadfe65190e1a/transformed/unzipped-distribution/gradle-8.2/build-logic/binary-compatibility/src/main/groovy/gradlebuild/binarycompatibility/rules/SinceAnnotationMissingRuleCurrentGradleVersionSetup.java'
# fatal: adding files failed

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'notebooks/02_numerical_analysis.ipynb'
