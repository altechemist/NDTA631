# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sqlite3
from openpyxl import Workbook
import warnings
warnings.filterwarnings('ignore')

print('Global Mobile Money Analysis')
print('=' * 50)
print('Analyzing mobile money adoption across ALL countries...')

# DATA LOADING AND PREPARATION 
print('\n Loading and preparing datasets...')
sent_df = pd.read_csv("C:/Users/202213306/Desktop/3rd Year (Sec)/DATA ANALYSIS AND VISUALIZATION/DATA ANALYSIS AND VISUALIZATION(Assignment)/WB_FINDEX_FIN13BM.csv")
withdrew_df = pd.read_csv("C:/Users/202213306/Desktop/3rd Year (Sec)/DATA ANALYSIS AND VISUALIZATION/DATA ANALYSIS AND VISUALIZATION(Assignment)/WB_FINDEX_FIN13CM.csv")

print(f' Sent Money Dataset: {sent_df.shape}')
print(f' Withdrew Money Dataset: {withdrew_df.shape}')

# Clean data by removing NaN values
sent_df_clean = sent_df.dropna(subset=['OBS_VALUE'])
withdrew_df_clean = withdrew_df.dropna(subset=['OBS_VALUE'])

print(f' Clean Sent Money Records: {len(sent_df_clean)}')
print(f' Clean Withdrew Money Records: {len(withdrew_df_clean)}')

print('')
print('GLOBAL STATISTICS')
print('=' * 30)

# Get unique countries
all_countries = sorted(list(set(sent_df_clean['REF_AREA'].unique()) | set(withdrew_df_clean['REF_AREA'].unique())))
print(f'Total Countries Analyzed: {len(all_countries)}')

# Calculate global averages
global_sent_avg = sent_df_clean['OBS_VALUE'].mean()
global_withdrew_avg = withdrew_df_clean['OBS_VALUE'].mean()
print(f' Global Average - Sent Money: {global_sent_avg:.2f}%')
print(f' Global Average - Withdrew Money: {global_withdrew_avg:.2f}%')

# === COUNTRY-BY-COUNTRY ANALYSIS ===
print('\n COUNTRY-BY-COUNTRY ANALYSIS')
print('=' * 40)

# Create comprehensive country comparison
country_stats = []

for country in all_countries:
    sent_data = sent_df_clean[sent_df_clean['REF_AREA'] == country]
    withdrew_data = withdrew_df_clean[withdrew_df_clean['REF_AREA'] == country]
    
    if len(sent_data) > 0 and len(withdrew_data) > 0:
        sent_mean = sent_data['OBS_VALUE'].mean()
        withdrew_mean = withdrew_data['OBS_VALUE'].mean()
        sent_std = sent_data['OBS_VALUE'].std()
        withdrew_std = withdrew_data['OBS_VALUE'].std()
        
        # Calculate adoption gap (sent - withdrew)
        adoption_gap = sent_mean - withdrew_mean
        
        country_stats.append({
            'Country_Code': country,
            'Country_Name': sent_data['REF_AREA_LABEL'].iloc[0] if len(sent_data) > 0 else 'Unknown',
            'Sent_Money_Mean': sent_mean,
            'Withdrew_Money_Mean': withdrew_mean,
            'Adoption_Gap': adoption_gap,
            'Sent_Std': sent_std,
            'Withdrew_Std': withdrew_std,
            'Total_Adoption': (sent_mean + withdrew_mean) / 2
        })

# Convert to DataFrame
country_df = pd.DataFrame(country_stats)
country_df = country_df.sort_values('Total_Adoption', ascending=False)

print(f' Countries with complete data: {len(country_df)}')
print('\n TOP 10 COUNTRIES BY TOTAL MOBILE MONEY ADOPTION:')
print(country_df[['Country_Name', 'Total_Adoption', 'Adoption_Gap']].head(10))

# === REGIONAL ANALYSIS ===
print('\n REGIONAL ANALYSIS')
print('=' * 25)

# Define regions based on country codes (simplified)
def get_region(country_code):
    if country_code in ['BEN', 'BFA', 'CIV', 'CMR', 'TCD', 'COD', 'COG', 'COM', 'ETH', 'GHA', 'GIN', 'KEN', 'MDG', 'MLI', 'MOZ', 'NER', 'NGA', 'RWA', 'SEN', 'SLE', 'TGO', 'UGA', 'ZAF', 'ZWE']:
        return 'Sub-Saharan Africa'
    elif country_code in ['BGD', 'KHM', 'IDN', 'LAO', 'MMR', 'PHL', 'THA', 'VNM']:
        return 'South & Southeast Asia'
    elif country_code in ['BWA', 'NAM']:
        return 'Southern Africa'
    elif country_code in ['HTI', 'JAM']:
        return 'Caribbean'
    else:
        return 'Other'

country_df['Region'] = country_df['Country_Code'].apply(get_region)

# Regional statistics
regional_stats = country_df.groupby('Region').agg({
    'Total_Adoption': ['mean', 'std', 'count'],
    'Adoption_Gap': 'mean'
}).round(2)

print('\n REGIONAL BREAKDOWN:')
print(regional_stats)
# Out:
# Global Mobile Money Analysis
# ==================================================
# Analyzing mobile money adoption across ALL countries...
#
#  Loading and preparing datasets...
#  Sent Money Dataset: (515, 37)
#  Withdrew Money Dataset: (515, 37)
#  Clean Sent Money Records: 333
#  Clean Withdrew Money Records: 320
#
# GLOBAL STATISTICS
# ==============================
# Total Countries Analyzed: 37
#  Global Average - Sent Money: 16.12%
#  Global Average - Withdrew Money: 16.13%
#
#  COUNTRY-BY-COUNTRY ANALYSIS
# ========================================
#  Countries with complete data: 37
#
#  TOP 10 COUNTRIES BY TOTAL MOBILE MONEY ADOPTION:
#    Country_Name  Total_Adoption  Adoption_Gap
# 17      Lesotho       26.688197     -0.841428
# 35       Zambia       25.647085      2.300069
# 29     Eswatini       20.159520     -0.408621
# 22      Namibia       20.133255      0.640041
# 26      Senegal       20.098869      5.006804
# 33       Uganda       19.937397      0.329928
# 14        Kenya       19.903881      1.940299
# 3      Botswana       19.374186      2.264745
# 19         Mali       18.316353     -2.152288
# 11        Ghana       17.036663      5.266355
#
#  REGIONAL ANALYSIS
# =========================
#
#  REGIONAL BREAKDOWN:
#                        Total_Adoption             Adoption_Gap
#                                  mean   std count         mean
# Region
# Other                           15.59  6.85    10        -0.14
# South & Southeast Asia           3.73  0.73     2        -0.55
# Southern Africa                 19.75  0.54     2         1.45
# Sub-Saharan Africa              10.98  5.98    23         0.37

# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "from scipy import stats\n",
    "import sqlite3\n",
    "from openpyxl import Workbook\n",
    "import warnings\n",
    "warnings.filterwarnings('ignore')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Global Mobile Money Analysis"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "print('Global Mobile Money Analysis')\n",
    "print('=' * 50)\n",
    "print('Analyzing mobile money adoption across ALL countries...')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# DATA LOADING AND PREPARATION\n",
    "print('\\n Loading and preparing datasets...')\n",
    "\n",
    "sent_df = pd.read_csv(\"C:/Users/202213306/Desktop/3rd Year (Sec)/DATA ANALYSIS AND VISUALIZATION/DATA ANALYSIS AND VISUALIZATION(Assignment)/WB_FINDEX_FIN13BM.csv\")\n",
    "withdrew_df = pd.read_csv(\"C:/Users/202213306/Desktop/3rd Year (Sec)/DATA ANALYSIS AND VISUALIZATION/DATA ANALYSIS AND VISUALIZATION(Assignment)/WB_FINDEX_FIN13CM.csv\")\n",
    "\n",
    "print(f' Sent Money Dataset: {sent_df.shape}')\n",
    "print(f' Withdrew Money Dataset: {withdrew_df.shape}')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Clean data by removing NaN values\n",
    "sent_df_clean = sent_df.dropna(subset=['OBS_VALUE'])\n",
    "withdrew_df_clean = withdrew_df.dropna(subset=['OBS_VALUE'])\n",
    "\n",
    "print(f' Clean Sent Money Records: {len(sent_df_clean)}')\n",
    "print(f' Clean Withdrew Money Records: {len(withdrew_df_clean)}')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "print('')\n",
    "print('GLOBAL STATISTICS')\n",
    "print('=' * 30)\n",
    "\n",
    "# Get unique countries\n",
    "all_countries = sorted(list(set(sent_df_clean['REF_AREA'].unique()) | set(withdrew_df_clean['REF_AREA'].unique())))\n",
    "print(f'Total Countries Analyzed: {len(all_countries)}')\n",
    "\n",
    "# Calculate global averages\n",
    "global_sent_avg = sent_df_clean['OBS_VALUE'].mean()\n",
    "global_withdrew_avg = withdrew_df_clean['OBS_VALUE'].mean()\n",
    "print(f' Global Average - Sent Money: {global_sent_avg:.2f}%')\n",
    "print(f' Global Average - Withdrew Money: {global_withdrew_avg:.2f}%')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# === COUNTRY-BY-COUNTRY ANALYSIS ===\n",
    "print('\\n COUNTRY-BY-COUNTRY ANALYSIS')\n",
    "print('=' * 40)\n",
    "\n",
    "country_stats = []\n",
    "\n",
    "for country in all_countries:\n",
    "    sent_data = sent_df_clean[sent_df_clean['REF_AREA'] == country]\n",
    "    withdrew_data = withdrew_df_clean[withdrew_df_clean['REF_AREA'] == country]\n",
    "    \n",
    "    if len(sent_data) > 0 and len(withdrew_data) > 0:\n",
    "        sent_mean = sent_data['OBS_VALUE'].mean()\n",
    "        withdrew_mean = withdrew_data['OBS_VALUE'].mean()\n",
    "        sent_std = sent_data['OBS_VALUE'].std()\n",
    "        withdrew_std = withdrew_data['OBS_VALUE'].std()\n",
    "        \n",
    "        adoption_gap = sent_mean - withdrew_mean\n",
    "        \n",
    "        country_stats.append({\n",
    "            'Country_Code': country,\n",
    "            'Country_Name': sent_data['REF_AREA_LABEL'].iloc[0] if len(sent_data) > 0 else 'Unknown',\n",
    "            'Sent_Money_Mean': sent_mean,\n",
    "            'Withdrew_Money_Mean': withdrew_mean,\n",
    "            'Adoption_Gap': adoption_gap,\n",
    "            'Sent_Std': sent_std,\n",
    "            'Withdrew_Std': withdrew_std,\n",
    "            'Total_Adoption': (sent_mean + withdrew_mean) / 2\n",
    "        })\n",
    "\n",
    "country_df = pd.DataFrame(country_stats)\n",
    "country_df = country_df.sort_values('Total_Adoption', ascending=False)\n",
    "\n",
    "print(f' Countries with complete data: {len(country_df)}')\n",
    "print('\\n TOP 10 COUNTRIES BY TOTAL MOBILE MONEY ADOPTION:')\n",
    "display(country_df[['Country_Name', 'Total_Adoption', 'Adoption_Gap']].head(10))"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# === REGIONAL ANALYSIS ===\n",
    "print('\\n REGIONAL ANALYSIS')\n",
    "print('=' * 25)\n",
    "\n",
    "def get_region(country_code):\n",
    "    if country_code in ['BEN','BFA','CIV','CMR','TCD','COD','COG','COM','ETH','GHA','GIN','KEN','MDG','MLI','MOZ','NER','NGA','RWA','SEN','SLE','TGO','UGA','ZAF','ZWE']:\n",
    "        return 'Sub-Saharan Africa'\n",
    "    elif country_code in ['BGD','KHM','IDN','LAO','MMR','PHL','THA','VNM']:\n",
    "        return 'South & Southeast Asia'\n",
    "    elif country_code in ['BWA','NAM']:\n",
    "        return 'Southern Africa'\n",
    "    elif country_code in ['HTI','JAM']:\n",
    "        return 'Caribbean'\n",
    "    else:\n",
    "        return 'Other'\n",
    "\n",
    "country_df['Region'] = country_df['Country_Code'].apply(get_region)\n",
    "\n",
    "regional_stats = country_df.groupby('Region').agg({\n",
    "    'Total_Adoption': ['mean', 'std', 'count'],\n",
    "    'Adoption_Gap': 'mean'\n",
    "}).round(2)\n",
    "\n",
    "print('\\n REGIONAL BREAKDOWN:')\n",
    "display(regional_stats)"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.13"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import pandas as pd\n",
#      10     "import numpy as np\n",
#      11     "import matplotlib.pyplot as plt\n",
#      12     "import seaborn as sns\n",
#      13     "from scipy import stats\n",
#      14     "import sqlite3\n",
#      15     "from openpyxl import Workbook\n",
#      16     "import warnings\n",
#      17     "warnings.filterwarnings('ignore')"
#      18    ]
#      19   },
#      20   {
#      21    "cell_type": "markdown",
#      22    "metadata": {},
#      23    "source": [
#      24     "## Global Mobile Money Analysis"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": null,
#      30    "metadata": {},
#      31    "outputs": [],
#      32    "source": [
#      33     "print('Global Mobile Money Analysis')\n",
#      34     "print('=' * 50)\n",
#      35     "print('Analyzing mobile money adoption across ALL countries...')"
#      36    ]
#      37   },
#      38   {
#      39    "cell_type": "code",
#      40    "execution_count": null,
#      41    "metadata": {},
#      42    "outputs": [],
#      43    "source": [
#      44     "# DATA LOADING AND PREPARATION\n",
#      45     "print('\\n Loading and preparing datasets...')\n",
#      46     "\n",
#      47     "sent_df = pd.read_csv(\"C:/Users/202213306/Desktop/3rd Year (Sec)/DATA ANALYSIS AND VISUALIZATION/DATA ANALYSIS AND VISUALIZATION(Assignment)/WB_FINDEX_FIN13BM.csv\")\n",
#      48     "withdrew_df = pd.read_csv(\"C:/Users/202213306/Desktop/3rd Year (Sec)/DATA ANALYSIS AND VISUALIZATION/DATA ANALYSIS AND VISUALIZATION(Assignment)/WB_FINDEX_FIN13CM.csv\")\n",
#      49     "\n",
#      50     "print(f' Sent Money Dataset: {sent_df.shape}')\n",
#      51     "print(f' Withdrew Money Dataset: {withdrew_df.shape}')"
#      52    ]
#      53   },
#      54   {
#      55    "cell_type": "code",
#      56    "execution_count": null,
#      57    "metadata": {},
#      58    "outputs": [],
#      59    "source": [
#      60     "# Clean data by removing NaN values\n",
#      61     "sent_df_clean = sent_df.dropna(subset=['OBS_VALUE'])\n",
#      62     "withdrew_df_clean = withdrew_df.dropna(subset=['OBS_VALUE'])\n",
#      63     "\n",
#      64     "print(f' Clean Sent Money Records: {len(sent_df_clean)}')\n",
#      65     "print(f' Clean Withdrew Money Records: {len(withdrew_df_clean)}')"
#      66    ]
#      67   },
#      68   {
#      69    "cell_type": "code",
#      70    "execution_count": null,
#      71    "metadata": {},
#      72    "outputs": [],
#      73    "source": [
#      74     "print('')\n",
#      75     "print('GLOBAL STATISTICS')\n",
#      76     "print('=' * 30)\n",
#      77     "\n",
#      78     "# Get unique countries\n",
#      79     "all_countries = sorted(list(set(sent_df_clean['REF_AREA'].unique()) | set(withdrew_df_clean['REF_AREA'].unique())))\n",
#      80     "print(f'Total Countries Analyzed: {len(all_countries)}')\n",
#      81     "\n",
#      82     "# Calculate global averages\n",
#      83     "global_sent_avg = sent_df_clean['OBS_VALUE'].mean()\n",
#      84     "global_withdrew_avg = withdrew_df_clean['OBS_VALUE'].mean()\n",
#      85     "print(f' Global Average - Sent Money: {global_sent_avg:.2f}%')\n",
#      86     "print(f' Global Average - Withdrew Money: {global_withdrew_avg:.2f}%')"
#      87    ]
#      88   },
#      89   {
#      90    "cell_type": "code",
#      91    "execution_count": null,
#      92    "metadata": {},
#      93    "outputs": [],
#      94    "source": [
#      95     "# === COUNTRY-BY-COUNTRY ANALYSIS ===\n",
#      96     "print('\\n COUNTRY-BY-COUNTRY ANALYSIS')\n",
#      97     "print('=' * 40)\n",
#      98     "\n",
#      99     "country_stats = []\n",
#     100     "\n",
#     101     "for country in all_countries:\n",
#     102     "    sent_data = sent_df_clean[sent_df_clean['REF_AREA'] == country]\n",
#     103     "    withdrew_data = withdrew_df_clean[withdrew_df_clean['REF_AREA'] == country]\n",
#     104     "    \n",
#     105     "    if len(sent_data) > 0 and len(withdrew_data) > 0:\n",
#     106     "        sent_mean = sent_data['OBS_VALUE'].mean()\n",
#     107     "        withdrew_mean = withdrew_data['OBS_VALUE'].mean()\n",
#     108     "        sent_std = sent_data['OBS_VALUE'].std()\n",
#     109     "        withdrew_std = withdrew_data['OBS_VALUE'].std()\n",
#     110     "        \n",
#     111     "        adoption_gap = sent_mean - withdrew_mean\n",
#     112     "        \n",
#     113     "        country_stats.append({\n",
#     114     "            'Country_Code': country,\n",
#     115     "            'Country_Name': sent_data['REF_AREA_LABEL'].iloc[0] if len(sent_data) > 0 else 'Unknown',\n",
#     116     "            'Sent_Money_Mean': sent_mean,\n",
#     117     "            'Withdrew_Money_Mean': withdrew_mean,\n",
#     118     "            'Adoption_Gap': adoption_gap,\n",
#     119     "            'Sent_Std': sent_std,\n",
#     120     "            'Withdrew_Std': withdrew_std,\n",
#     121     "            'Total_Adoption': (sent_mean + withdrew_mean) / 2\n",
#     122     "        })\n",
#     123     "\n",
#     124     "country_df = pd.DataFrame(country_stats)\n",
#     125     "country_df = country_df.sort_values('Total_Adoption', ascending=False)\n",
#     126     "\n",
#     127     "print(f' Countries with complete data: {len(country_df)}')\n",
#     128     "print('\\n TOP 10 COUNTRIES BY TOTAL MOBILE MONEY ADOPTION:')\n",
#     129     "display(country_df[['Country_Name', 'Total_Adoption', 'Adoption_Gap']].head(10))"
#     130    ]
#     131   },
#     132   {
#     133    "cell_type": "code",
#     134    "execution_count": null,
#     135    "metadata": {},
#     136    "outputs": [],
#     137    "source": [
#     138     "# === REGIONAL ANALYSIS ===\n",
#     139     "print('\\n REGIONAL ANALYSIS')\n",
#     140     "print('=' * 25)\n",
#     141     "\n",
#     142     "def get_region(country_code):\n",
#     143     "    if country_code in ['BEN','BFA','CIV','CMR','TCD','COD','COG','COM','ETH','GHA','GIN','KEN','MDG','MLI','MOZ','NER','NGA','RWA','SEN','SLE','TGO','UGA','ZAF','ZWE']:\n",
#     144     "        return 'Sub-Saharan Africa'\n",
#     145     "    elif country_code in ['BGD','KHM','IDN','LAO','MMR','PHL','THA','VNM']:\n",
#     146     "        return 'South & Southeast Asia'\n",
#     147     "    elif country_code in ['BWA','NAM']:\n",
#     148     "        return 'Southern Africa'\n",
#     149     "    elif country_code in ['HTI','JAM']:\n",
#     150     "        return 'Caribbean'\n",
#     151     "    else:\n",
#     152     "        return 'Other'\n",
#     153     "\n",
#     154     "country_df['Region'] = country_df['Country_Code'].apply(get_region)\n",
#     155     "\n",
#     156     "regional_stats = country_df.groupby('Region').agg({\n",
#     157     "    'Total_Adoption': ['mean', 'std', 'count'],\n",
#     158     "    'Adoption_Gap': 'mean'\n",
#     159     "}).round(2)\n",
#     160     "\n",
#     161     "print('\\n REGIONAL BREAKDOWN:')\n",
#     162     "display(regional_stats)"
#     163    ]
#     164   }
#     165  ],
#     166  "metadata": {
#     167   "kernelspec": {
#     168    "display_name": "Python 3",
#     169    "language": "python",
#     170    "name": "python3"
#     171   },
#     172   "language_info": {
#     173    "name": "python",
#     174    "version": "3.13"
#     175   }
#     176  },
#     177  "nbformat": 4,
#     178  "nbformat_minor": 5
#     179 }
#
# NameError: name 'null' is not defined
